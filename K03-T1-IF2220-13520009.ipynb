# %% [markdown]
# # Tugas Besar IF2220 Probabilitas dan Statistika
# ## Penarikan Kesimpulan dan Pengujian Hipotesis
# Anggota:
# - 13520009 - Ahmad Romy Zahran
# - 13520036 - I Gede Arya Raditya Parameswara
#
# Diberikan sebuah data water_potability.csv yang merupakan data metrik kualitas air dan mengandung 11 kolom sebagai berikut:
# 1. id
# 2. pH
# 3. Hardness
# 4. Solids
# 5. Chloramines
# 6. Sulfate
# 7. Conductivity
# 8. OrganicCarbon
# 9. Trihalomethanes
# 10. Turbidity
# 11. Potability
#
# Kolom 2-10 adalah kolom atribut (non-target), sedangkan kolom 11 adalah kolom target.

# %% [markdown]
# # Persiapan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

df = pd.read_csv("water_potability.csv", names=["id","pH","Hardness","Solids","Chloramines", "Sulfate", "Conductivity", "OrganicCarbon", "Trihalomethanes", "Turbidity", "Potability"])
df
# Out:
#         id         pH    Hardness        Solids  Chloramines     Sulfate  \
# 0        1   8.316766  214.373394  22018.417441     8.059332  356.886136
# 1        2   9.092223  181.101509  17978.986339     6.546600  310.135738
# 2        3   5.584087  188.313324  28748.687739     7.544869  326.678363
# 3        4  10.223862  248.071735  28749.716544     7.513408  393.663396
# 4        5   8.635849  203.361523  13672.091764     4.563009  303.309771
# ...    ...        ...         ...           ...          ...         ...
# 2005  2006   8.197353  203.105091  27701.794055     6.472914  328.886838
# 2006  2007   8.989900  215.047358  15921.412018     6.297312  312.931022
# 2007  2008   6.702547  207.321086  17246.920347     7.708117  304.510230
# 2008  2009  11.491011   94.812545  37188.826022     9.263166  258.930600
# 2009  2010   6.069616  186.659040  26138.780191     7.747547  345.700257
#
#       Conductivity  OrganicCarbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
df.dtypes
# Out:
# id                   int64
# pH                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# OrganicCarbon      float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                 0
# pH                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# OrganicCarbon      0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# # Nomor 1
# Menulis deskripsi statistika (Descriptive Statistics) dari semua kolom pada data yang bersifat numerik, terdiri dari mean, median, modus, standar deviasi, variansi, range, nilai minimum, maksimum, kuartil, IQR, skewness dan kurtosis.

# %%
def describeColumn(df):
  print("Mean: ", df.mean())
  print("Median: ", df.median())
  print("Modus: ", df.mode())
  print("Standar deviasi: ", df.std())
  print("Variansi: ", df.var())
  print("Range: ", df.max()-df.min())
  print("Nilai Minimum: ", df.min())
  print("Nilai Maksimum: ", df.max())
  print("Kuartil pertama: ", df.quantile(0.25))
  print("Kuartil kedua: ", df.quantile(0.5))
  print("Kuartil ketiga: ", df.quantile(0.75))
  print("IQR: ", df.quantile(0.75)-df.quantile(0.25))
  print("Skewness: ", df.skew())
  print("Kurtosis: ", df.kurtosis())

# %% [markdown]
# ### id
# Deskripsi statistika dari kolom id:

# %%
describeColumn(df["id"])
# Out:
# Mean:  1005.5
# Median:  1005.5
# Modus:  0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2005    2006
# 2006    2007
# 2007    2008
# 2008    2009
# 2009    2010
# Length: 2010, dtype: int64
# Standar deviasi:  580.381340154902
# Variansi:  336842.5
# Range:  2009
# Nilai Minimum:  1
# Nilai Maksimum:  2010
# Kuartil pertama:  503.25
# Kuartil kedua:  1005.5
# Kuartil ketiga:  1507.75
# IQR:  1004.5
# Skewness:  0.0
# Kurtosis:  -1.2

# %% [markdown]
# ### pH
# Deskripsi statistika dari kolom pH:

# %%
describeColumn(df["pH"])
# Out:
# Mean:  7.0871927687138205
# Median:  7.029490455474185
# Modus:  0        0.227499
# 1        0.989912
# 2        1.431782
# 3        1.757037
# 4        1.985383
#           ...
# 2005    11.568768
# 2006    11.898078
# 2007    12.246928
# 2008    13.349889
# 2009    14.000000
# Length: 2010, dtype: float64
# Standar deviasi:  1.5728029470456644
# Variansi:  2.473709110235527
# Range:  13.7725009497978
# Nilai Minimum:  0.2274990502021987
# Nilai Maksimum:  13.999999999999998
# Kuartil pertama:  6.09078502142353
# Kuartil kedua:  7.029490455474185
# Kuartil ketiga:  8.053006240791538
# IQR:  1.9622212193680078
# Skewness:  0.04853451405270669
# Kurtosis:  0.6269041256617065

# %% [markdown]
# ### Hardness
# Deskripsi statistika dari kolom Hardness:

# %%
describeColumn(df["Hardness"])
# Out:
# Mean:  195.96920903783553
# Median:  197.20352491941043
# Modus:  0        73.492234
# 1        77.459586
# 2        81.710895
# 3        94.091307
# 4        94.812545
#            ...
# 2005    286.567991
# 2006    287.975540
# 2007    300.292476
# 2008    306.627481
# 2009    317.338124
# Length: 2010, dtype: float64
# Standar deviasi:  32.64316585942984
# Variansi:  1065.5762773262459
# Range:  243.84589036652147
# Nilai Minimum:  73.4922336890611
# Nilai Maksimum:  317.33812405558257
# Kuartil pertama:  176.74065667669896
# Kuartil kedua:  197.20352491941043
# Kuartil ketiga:  216.44758866727156
# IQR:  39.7069319905726
# Skewness:  -0.08532104172868622
# Kurtosis:  0.5254804942991402

# %% [markdown]
# ### Solids
# Deskripsi statistika dari kolom Solids:

# %%
describeColumn(df["Solids"])
# Out:
# Mean:  21904.67343905309
# Median:  20926.88215534375
# Modus:  0         320.942611
# 1        1198.943699
# 2        1351.906979
# 3        1372.091043
# 4        2552.962804
#             ...
# 2005    50793.898917
# 2006    53735.899194
# 2007    55334.702799
# 2008    56351.396304
# 2009    56488.672413
# Length: 2010, dtype: float64
# Standar deviasi:  8625.39791119058
# Variansi:  74397489.12637082
# Range:  56167.72980146483
# Nilai Minimum:  320.942611274359
# Nilai Maksimum:  56488.67241273919
# Kuartil pertama:  15614.412961614333
# Kuartil kedua:  20926.88215534375
# Kuartil ketiga:  27170.534648603603
# IQR:  11556.12168698927
# Skewness:  0.5910113724580447
# Kurtosis:  0.33732026745944976

# %% [markdown]
# ### Chloramines
# Deskripsi statistika dari kolom Chloramines:

# %%
describeColumn(df["Chloramines"])
# Out:
# Mean:  7.134322344600092
# Median:  7.1420143046226645
# Modus:  0        1.390871
# 1        1.920271
# 2        2.397985
# 3        2.456014
# 4        2.458609
#           ...
# 2005    12.580026
# 2006    12.626900
# 2007    12.653362
# 2008    13.043806
# 2009    13.127000
# Length: 2010, dtype: float64
# Standar deviasi:  1.5852140982642096
# Variansi:  2.5129037373356113
# Range:  11.736129095114823
# Nilai Minimum:  1.3908709048851806
# Nilai Maksimum:  13.127000000000002
# Kuartil pertama:  6.138326387572855
# Kuartil kedua:  7.1420143046226645
# Kuartil ketiga:  8.109933216133502
# IQR:  1.9716068285606472
# Skewness:  0.013003497779569528
# Kurtosis:  0.5497821097667472

# %% [markdown]
# ### Sulfate
# Deskripsi statistika dari kolom Sulfate:

# %%
describeColumn(df["Sulfate"])
# Out:
# Mean:  333.21137641518925
# Median:  332.2141128069568
# Modus:  0       129.000000
# 1       180.206746
# 2       182.397370
# 3       187.170714
# 4       187.424131
#            ...
# 2005    458.441072
# 2006    460.107069
# 2007    475.737460
# 2008    476.539717
# 2009    481.030642
# Length: 2010, dtype: float64
# Standar deviasi:  41.21111102560977
# Variansi:  1698.355671965135
# Range:  352.03064230599716
# Nilai Minimum:  129.00000000000003
# Nilai Maksimum:  481.0306423059972
# Kuartil pertama:  307.6269864860709
# Kuartil kedua:  332.2141128069568
# Kuartil ketiga:  359.26814739141554
# IQR:  51.641160905344634
# Skewness:  -0.04572780443653543
# Kurtosis:  0.7868544988131605

# %% [markdown]
# ### Conductivity
# Deskripsi statistika dari kolom Conductivity:

# %%
describeColumn(df["Conductivity"])
# Out:
# Mean:  426.4767083525792
# Median:  423.43837202443706
# Modus:  0       201.619737
# 1       210.319182
# 2       233.907965
# 3       245.859632
# 4       252.968328
#            ...
# 2005    666.690618
# 2006    669.725086
# 2007    695.369528
# 2008    708.226364
# 2009    753.342620
# Length: 2010, dtype: float64
# Standar deviasi:  80.70187180729437
# Variansi:  6512.792113200974
# Range:  551.7228828031471
# Nilai Minimum:  201.6197367551575
# Nilai Maksimum:  753.3426195583046
# Kuartil pertama:  366.61921929632433
# Kuartil kedua:  423.43837202443706
# Kuartil ketiga:  482.2097724598859
# IQR:  115.5905531635616
# Skewness:  0.26801233302645316
# Kurtosis:  -0.23720600574806516

# %% [markdown]
# ### OrganicCarbon
# Deskripsi statistika dari kolom OrganicCarbon:

# %%
describeColumn(df["OrganicCarbon"])
# Out:
# Mean:  14.357939902048088
# Median:  14.323285610653329
# Modus:  0        2.200000
# 1        4.371899
# 2        4.466772
# 3        4.861631
# 4        4.966862
#           ...
# 2005    23.569645
# 2006    23.604298
# 2007    23.917601
# 2008    24.755392
# 2009    27.006707
# Length: 2010, dtype: float64
# Standar deviasi:  3.3257700016987193
# Variansi:  11.060746104199099
# Range:  24.80670661116602
# Nilai Minimum:  2.1999999999999886
# Nilai Maksimum:  27.00670661116601
# Kuartil pertama:  12.122530374047727
# Kuartil kedua:  14.323285610653329
# Kuartil ketiga:  16.683561746173808
# IQR:  4.561031372126081
# Skewness:  -0.02021975629181238
# Kurtosis:  0.031018388192253

# %% [markdown]
# ### Trihalomethanes
# Deskripsi statistika dari kolom Trihalomethanes:

# %%
describeColumn(df["Trihalomethanes"])
# Out:
# Mean:  66.40071666307463
# Median:  66.48204080309809
# Modus:  0         8.577013
# 1        14.343161
# 2        15.684877
# 3        16.291505
# 4        17.527765
#            ...
# 2005    114.034946
# 2006    114.208671
# 2007    116.161622
# 2008    120.030077
# 2009    124.000000
# Length: 2010, dtype: float64
# Standar deviasi:  16.08110898232513
# Variansi:  258.602066101418
# Range:  115.4229870670162
# Nilai Minimum:  8.577012932983806
# Nilai Maksimum:  124.0
# Kuartil pertama:  55.94999302803186
# Kuartil kedua:  66.48204080309809
# Kuartil ketiga:  77.2946128060674
# IQR:  21.344619778035543
# Skewness:  -0.05138268451619478
# Kurtosis:  0.2230167810639787

# %% [markdown]
# ### Turbidity
# Deskripsi statistika dari kolom Turbidity:

# %%
describeColumn(df["Turbidity"])
# Out:
# Mean:  3.969496912630371
# Median:  3.967373963531836
# Modus:  0       1.450000
# 1       1.492207
# 2       1.496101
# 3       1.680554
# 4       1.812529
#           ...
# 2005    6.307678
# 2006    6.357439
# 2007    6.389161
# 2008    6.494249
# 2009    6.494749
# Length: 2010, dtype: float64
# Standar deviasi:  0.7804710407083955
# Variansi:  0.6091350453844459
# Range:  5.044748555990993
# Nilai Minimum:  1.45
# Nilai Maksimum:  6.494748555990993
# Kuartil pertama:  3.442881623557439
# Kuartil kedua:  3.967373963531836
# Kuartil ketiga:  4.5146627202018825
# IQR:  1.0717810966444437
# Skewness:  -0.03226597968019271
# Kurtosis:  -0.049830796949249745

# %% [markdown]
# ### Potability
# Deskripsi statistika dari kolom Potability:

# %%
describeColumn(df["Potability"])
# Out:
# Mean:  0.40298507462686567
# Median:  0.0
# Modus:  0    0
# dtype: int64
# Standar deviasi:  0.4906198726190973
# Variansi:  0.24070785940877926
# Range:  1
# Nilai Minimum:  0
# Nilai Maksimum:  1
# Kuartil pertama:  0.0
# Kuartil kedua:  0.0
# Kuartil ketiga:  1.0
# IQR:  1.0
# Skewness:  0.39587289143607485
# Kurtosis:  -1.8451215871809596

# %% [markdown]
# # Nomor 2
# Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot tersebut.

# %%
def distributedPlot(df, i):
  df.boxplot(column = [df.columns[i]], figsize=(6, 4))
  df.hist(column = [df.columns[i]], bins=30, color = "#525E75")
  print(df.columns[i] + " skewness: " + str(df[df.columns[i]].skew()))

# %% [markdown]
# ### pH
# Visualisasi histogram dan boxplot pada kolom pH:

# %%
distributedPlot(df, 1)
# Out:
# pH skewness: 0.04853451405270669

# %% [markdown]
# - Berdasarkan Box Plotnya, pH memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa pH tidak terdistribusi secara normal dan condong sedikit ke arah kiri yang berarti positively skewed.

# %% [markdown]
# ### Hardness
# Visualisasi histogram dan boxplot pada kolom hardness:

# %%
distributedPlot(df, 2)
# Out:
# Hardness skewness: -0.08532104172868622

# %% [markdown]
# - Berdasarkan Box Plotnya, Hardness memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Hardness tidak terdistribusi secara normal dan condong sedikit ke arah kanan yang berarti negatively skewed.

# %% [markdown]
# ### Solids
# Visualisasi histogram dan boxplot pada kolom solids:

# %%
distributedPlot(df, 3)
# Out:
# Solids skewness: 0.5910113724580447

# %% [markdown]
# - Berdasarkan Box Plotnya, Solids memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Solids tidak terdistribusi secara normal dan condong sedikit ke arah kiri yang berarti positively skewed.

# %% [markdown]
# ### Chloramines
# Visualisasi histogram dan boxplot pada kolom chloramines:

# %%
distributedPlot(df, 4)
# Out:
# Chloramines skewness: 0.013003497779569528

# %% [markdown]
# - Berdasarkan Box Plotnya, Chloramines memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Chloramines tidak terdistribusi secara normal dan condong sedikit ke arah kiri yang berarti positively skewed.

# %% [markdown]
# ### Sulfate
# Visualisasi histogram dan boxplot pada kolom sulfate:

# %%
distributedPlot(df, 5)
# Out:
# Sulfate skewness: -0.04572780443653543

# %% [markdown]
# - Berdasarkan Box Plotnya, Sulfate memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Sulfate tidak terdistribusi secara normal dan condong sedikit ke arah kanan yang berarti negatively skewed.

# %% [markdown]
# ### Conductivity
# Visualisasi histogram dan boxplot pada kolom conductivity:

# %%
distributedPlot(df, 6)
# Out:
# Conductivity skewness: 0.26801233302645316

# %% [markdown]
# - Berdasarkan Box Plotnya, Conductivity memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Conductivity tidak terdistribusi secara normal dan condong sedikit ke arah kiri yang berarti positively skewed.

# %% [markdown]
# ### OrganicCarbon
# Visualisasi histogram dan boxplot pada kolom organic carbon:

# %%
distributedPlot(df, 7)
# Out:
# OrganicCarbon skewness: -0.02021975629181238

# %% [markdown]
# - Berdasarkan Box Plotnya, OrganicCarbon memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa OrganicCarbon terdistribusi secara normal.

# %% [markdown]
# ### Trihalomethanes
# Visualisasi histogram dan boxplot pada kolom trihalomethanes:

# %%
distributedPlot(df, 8)
# Out:
# Trihalomethanes skewness: -0.05138268451619478

# %% [markdown]
# - Berdasarkan Box Plotnya, Trihalomethanes memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Trihalomethanes terdistribusi secara normal.

# %% [markdown]
# ### Turbidity
# Visualisasi histogram dan boxplot pada kolom turbidity:

# %%
distributedPlot(df, 9)
# Out:
# Turbidity skewness: -0.03226597968019271

# %% [markdown]
# - Berdasarkan Box Plotnya, Turbidity memiliki titik outlier.
# - Berdasarkan grafiknya terlihat bahwa Turbidity terdistribusi secara normal.

# %% [markdown]
# ### Potability
# Visualisasi histogram dan boxplot pada kolom potability:

# %%
distributedPlot(df, 10)
# Out:
# Potability skewness: 0.39587289143607485

# %% [markdown]
# - Berdasarkan Box Plotnya, Potabiity tidak memiliki outlier.
# - Berdasarkan grafiknya terlihat jelas bahwa Potability tidak terdistribusi secara normal.

# %% [markdown]
# # Nomor 3
# Menentukan setiap kolom numerik berdistribusi normal atau tidak dari histogram sebelumnya.

# %%
def normalTest(df, i):
  alpha = 0.05
  val, p_value = st.normaltest(df[df.columns[i]])
  print("P-value: ", p_value)
  if(p_value>alpha):
    print(df.columns[i] + " berdistribusi normal")
  else:
    print(df.columns[i] + " tidak berdistribusi normal")

for i in range(11):
  normalTest(df, i)
# Out:
# P-value:  0.0
# id tidak berdistribusi normal
# P-value:  2.6514813346797777e-05
# pH tidak berdistribusi normal
# P-value:  0.00013442428699593753
# Hardness tidak berdistribusi normal
# P-value:  2.0796613688739523e-24
# Solids tidak berdistribusi normal
# P-value:  0.0002504831654753917
# Chloramines tidak berdistribusi normal
# P-value:  4.4255936678013136e-07
# Sulfate tidak berdistribusi normal
# P-value:  4.39018078287845e-07
# Conductivity tidak berdistribusi normal
# P-value:  0.8825496581408284
# OrganicCarbon berdistribusi normal
# P-value:  0.1043598441875204
# Trihalomethanes berdistribusi normal
# P-value:  0.7694717369961169
# Turbidity berdistribusi normal
# P-value:  0.0
# Potability tidak berdistribusi normal

# %% [markdown]
# ### id
# Kolom id tidak berdistribusi normal, namun berdistribusi uniform karena nilai tersebar merata. Dengan nilai median=mean, tidak ada pencilan, dan nilai skewness=0.0.
# ### pH
# Kolom pH tidak berdistribusi normal dan cenderung positively skewed dengan nilai skewness = 0.048. Nilai median sedikit lebih kecil dari mean dan memiliki pencilan di kedua ujung.
# ### Hardness
# Kolom Hardness tidak berdistribusi normal dan cenderung negatively skewed dengan nilai skewness = -0.085. Nilai median > mean dan memiliki pencilan di kedua ujung.
# ### Solids
# Kolom Solids berdistribusi positively skewed karena lebih banyak nilai rendah dan memiliki pencilan di sisi yang bernilai tinggi. Dengan nilai median < mean dan nilai skewness = 0.591.
# ### Chloramines
# Kolom Chloramines tidak berdistribusi normal dan cenderung positively skewed dengan nilai skewness = 0.013. Dengan pencilan di kedua ujung namun nilai median sedikit lebih besar dari mean.
# ### Sulfate
# Kolom Sulfate tidak berdistribusi normal dan cenderung negatively skewed dengan nilai skewness = -0.045. Dengan pencilan di kedua ujung dengan pencilan di sisi yang leibh rendah bernilai sangat kecil namun nilai median < mean.
# ### Conductivity
# Kolom Conductivity berdistribusi positively skewed karena memiliki nilai skewness = 0.268. Dengan nilai median < mean, lebih banyak nilai rendah, dan memiliki pencilan di sisi yang bernilai tinggi.
# ### OrganicCarbon
# Kolom OrganicCarbon berdistribusi normal dengan nilai skewness = -0.02. Dengan nilai median mendekati mean, namun memiliki pencilan di kedua ujung.
# ### Trihalomethanes
# Kolom Trihalomethanes berdistribusi normal dengan nilai skewness = -0.05. Dengan nilai median mendekati mean, namun memiliki pencilan di kedua ujung.
# ### Turbidity
# Kolom Turbidity berdistribusi normal dengan nilai skewness = -0.03. Dengan nilai median mendekati mean, namun memiliki pencilan di kedua ujung.
# ### Potability
# Kolom Potability tidak berdistribusi normal dan cenderung positively skewed dnegan nilai skewness = 0.395. Dengan nilai median < mean.

# %% [markdown]
# # Nomor 4
#
# Melakukan test hipotesis 1 sampel, dengan menuliskan 6 langkah testing dan menampilkan juga boxplotnya untuk kolom/bagian yang bersesuaian.

# %% [markdown]
# ### a. Nilai Rata-rata pH di atas 7?

# %%
phbp = df.boxplot(["pH"])
phbp.set_title("Boxplot pH")
plt.show()

# %% [markdown]
# 1. $H_0: \mu_{pH} = 7 $
# 2. $H_1: \mu_{pH} \gt 7 $
# 3. $\alpha = 0.05$
# 4. Uji statistik dengan $ z = \frac{mean-\mu}{\frac{\sigma}{\sqrt{n}}}$ dan daerah kritis $z > z_{\alpha} = 1.6448$
# 5. Menghitung nilai uji statistik

# %%
mean = 7
mu = df["pH"].mean()
std = df["pH"].std()
n = df["pH"].count()
z = (mu - mean) * (n**(0.5)) / std
p_val = 1 - st.norm.cdf(abs(z))
print("z = " + str(z))
print("p-value = " + str(p_val))
# Out:
# z = 2.485445147379661
# p-value = 0.0064694762889006

# %% [markdown]
# 6. Karena nilai $z = 2.485 > z_a$ sehingga berada pada daerah kritis, maka hipotesis $H_0$ ditolak dan rata-rata pH lebih dari 7

# %% [markdown]
# ### b. Nilai Rata-rata Hardness tidak sama dengan 205?

# %%
hdbp = df.boxplot(["Hardness"])
hdbp.set_title("Boxplot Hardness")
plt.show()

# %% [markdown]
# 1. $H_0: \mu_{Hardness} = 205 $
# 2. $H_1: \mu_{Hardness} \neq 205 $
# 3. $\alpha = 0.05$
# 4. Uji statistik dengan $ z = \frac{mean-\mu}{\frac{\sigma}{\sqrt{n}}}$ dan daerah kritis $z < -z_{\frac{\alpha}{2}}$ atau $z > z_{\frac{\alpha}{2}}$ dengan $z_{\frac{\alpha}{2}} = 1.9599$
# 5. Menghitung nilai uji statistik

# %%
mean = 205
mu = df["Hardness"].mean()
std = df["Hardness"].std()
n = df["Hardness"].count()
z = (mu - mean) * (n**(0.5)) / std
p_val = (1 - st.norm.cdf(abs(z)))*2
print("z = " + str(z))
print("p-value = " + str(p_val))
# Out:
# z = -12.40313717001035
# p-value = 0.0

# %% [markdown]
# 6. Karena $z = -12.403 < -z_{\frac{\alpha}{2}}$ sehingga berada pada daerah kritis, maka hipotesis $H_0$ ditolak dan menyimpulkan rata-rata Hardness tidak sama dengan 205

# %% [markdown]
# ### c. Nilai Rata-rata 100 baris pertama kolom Solids bukan 21900?

# %%
sbp = df.loc[:100].boxplot(["Solids"])
sbp.set_title("Boxplot 100 baris pertama kolom Solids")
plt.show()

# %% [markdown]
# 1. $H_0: \mu_{Solids} = 21900 $
# 2. $H_1: \mu_{Solids} \neq 21900 $
# 3. $\alpha = 0.05$
# 4. Uji statistik dengan $ z = \frac{mean-\mu}{\frac{\sigma}{\sqrt{n}}}$ dan daerah kritis $z < -z_{\frac{\alpha}{2}}$ atau $z > z_{\frac{\alpha}{2}}$ dengan $z_{\frac{\alpha}{2}} = 1.9599$
# 5. Menghitung nilai uji statistik

# %%
mean = 21900
mu = df["Solids"][:100].mean()
std = df["Solids"][:100].std()
n = df["Solids"][:100].count()
z = (mu - mean) * (n**(0.5)) / std
p_val = min(1 - st.norm.cdf(abs(z)),st.norm.cdf(abs(z)))*2
print("z = " + str(z))
print("p-value = " + str(p_val))
# Out:
# z = 0.5636797715721505
# p-value = 0.5729720864655206

# %% [markdown]
# 6. Karena  $z = 0.5636$ tidak berada pada daerah kritis, maka hipotesis $H_0$ tidak ditolak dan rata-rata 100 baris pertama Solids sama dengan 21900

# %% [markdown]
# ### d. Proporsi nilai Conductivity yang lebih dari 450, adalah tidak sama dengan 10%?

# %%
cbp = df.boxplot(["Conductivity"])
cbp.set_title("Boxplot Conductivity")
plt.show()

# %% [markdown]
# 1. $H_0: p = 0.1 $
# 2. $H_1: p \neq 0.1 $
# 3. $\alpha = 0.05$
# 4. Uji statistik dengan $ z = \frac{x-n*p_0}{\sqrt{n*p_0*q_0}}$ dan daerah kritis $z < -z_{\frac{\alpha}{2}}$ atau $z > z_{\frac{\alpha}{2}}$ dengan $z_{\frac{\alpha}{2}} = 1.9599$
# 5. Menghitung nilai uji statistik

# %%
a = 0.05
p0 = 0.1
q0 = 1 - p0
x = 0
n = df["Conductivity"].count()
for i in range(len(df["Conductivity"])):
  if(df["Conductivity"][i] > 450):
    x+=1
z = (x - n*p0)/((n*p0*q0)**0.5)
p_val = (1 - st.norm.cdf(abs(z)))*2
print("z = " + str(z))
print("p-value = " + str(p_val))
# Out:
# z = 40.446376131589325
# p-value = 0.0

# %% [markdown]
# 6. Karena $z = 40.4463 > z_{\frac{\alpha}{2}}$ sehingga berada pada daerah kritis, maka hipotesis $H_0$ ditolak dan proporsi nilai Conductivity yang lebih dari 450 tidak sama dengan 10%

# %% [markdown]
# ### e. Proporsi nilai Trihalomethanes yang kurang dari 40, adalah kurang dari 5%?

# %%
tbp = df.loc[:99].boxplot(["Trihalomethanes"])
tbp.set_title("Boxplot Trihalomethanes")
plt.show()

# %% [markdown]
# 1. $H_0: p = 0.05 $
# 2. $H_1: p \lt 0.05 $
# 3. $\alpha = 0.05$
# 4. Uji statistik dengan $ z = \frac{x-n*p_0}{\sqrt{n*p_0*q_0}}$ dan daerah kritis $z < -z_{\alpha}$dengan $z_{\alpha} = 1.6448$
# 5. Menghitung nilai uji statistik

# %%
a = 0.05
p0 = 0.05
q0 = 1 - p0
x = 0
n = df["Trihalomethanes"].count()
for i in range(len(df["Trihalomethanes"])):
  if(df["Trihalomethanes"][i] < 40):
    x+=1
z = (x - n*p0)/((n*p0*q0)**0.5)
p_val = st.norm.cdf(abs(z))
print("z = " + str(z))
print("p-value = " + str(p_val))
# Out:
# z = 0.5628826416670959
# p-value = 0.7132425995092373

# %% [markdown]
# 6. Karena $z = 0.5628$ tidak berada pada daerah kritis, maka hipotesis $H_0$ tidak ditolak dan proporsi nilai Trihalomethanes yang kurang dari 40 bernilai 5%

# %% [markdown]
# # Nomor 5
# Melakukan test hipotesis 2 sampel, dengan menuliskan 6 langkah testing dan menampilkan juga boxplotnya untuk kolom/bagian yang bersesuaian.
#
# Asumsi: seluruh sampel diambil dari populasi yang berdistribusi normal.

# %% [markdown]
# ### a. Data kolom Sulfate dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata kedua bagian tersebut sama?

# %%
ax = df.loc[:1004].boxplot(["Sulfate"])
ax.set_title("Boxplot A1")
plt.show()

# %%
ax = df.loc[1005:].boxplot(["Sulfate"])
ax.set_title("Boxplot A2")
plt.show()

# %% [markdown]
# 1. H0: $\mu_{A1} = \mu_{A2} $
# 2. H1: $\mu_{A1} \neq \mu_{A2} $
# 3. $\alpha = 0.05$
# 4. Menentukan daerah kritis dengan distribusi normal dan uji statistik two-sample: test on two mean with known variances. note: Saat n>30, distribusi t tidak berbeda signifikan dengan distribusi normal dan S estimasi yang baik untuk $\sigma$.

# %%
za = st.norm.ppf(1-0.025)
print("Batas bawah: ",za)
print("Batas atas: ", -za)
# Out:
# Batas bawah:  1.959963984540054
# Batas atas:  -1.959963984540054

# %% [markdown]
# Didapat daerah kritis: $z < -z_{\alpha/2}$ or $z > z_{\alpha/2}$: $z < -1.960$ or $z > 1.960$
# 5. Menghitung nilai uji statistik dan p-value

# %%
from math import sqrt
n1 = 1005
n2 = 1005
x1 = df.loc[:1004, "Sulfate"].mean()
x2 = df.loc[1005:, "Sulfate"].mean()
s1_2 = df.loc[:1004, "Sulfate"].var()
s2_2 = df.loc[1005:, "Sulfate"].var()
z_value = (x1-x2)/sqrt(s1_2/n1 + s2_2/n2)
p_value = 2*min(1 - st.norm.cdf(abs(z_value)),st.norm.cdf(abs(z_value)))
print("Nilai z: ", z_value)
print("Nilai p: ", p_value)
# Out:
# Nilai z:  -2.0752690696873217
# Nilai p:  0.0379616043851172

# %% [markdown]
# 6. Nilai z yang didapat berada dalam daerah kritis (-2.075<-1.960) dan p-value < $\alpha$. Oleh karena itu, keputusan yang diambil adalah menolak H0 dan menyimpulkan rata-rata kedua bagian tidak sama.

# %% [markdown]
# ### b. Data kolom OrganicCarbon dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata bagian awal lebih besar dari pada bagian akhir sebesar 0.15?

# %%
ax = df.loc[:1004].boxplot(["OrganicCarbon"])
ax.set_title("Boxplot A1")
plt.show()

# %%
ax = df.loc[1005:].boxplot(["OrganicCarbon"])
ax.set_title("Boxplot A2")
plt.show()

# %% [markdown]
# 1. $H0: \mu_{A1} - \mu_{A2} = 0.15$
# 2. $H1: \mu_{A1} - \mu_{A2} \neq 0.15$
# 3. $\alpha = 0.05$
# 4. Menentukan daerah kritis dengan distribusi normal dan uji statistik two-sample: test on two mean with known variances. note: Saat n>30, distribusi t tidak berbeda signifikan dengan distribusi normal dan S estimasi yang baik untuk $\sigma$.

# %%
za = st.norm.ppf(1-0.025)
print("Batas bawah: ",za)
print("Batas atas: ", -za)
# Out:
# Batas bawah:  1.959963984540054
# Batas atas:  -1.959963984540054

# %% [markdown]
# Didapat daerah kritis: $z < -z_{\alpha/2}$ or $z > z_{\alpha/2}$: $z < -1.960$ or $z > 1.960$
# 5. Menghitung nilai uji statistik dan p-value

# %%
from math import sqrt
n1 = 1005
n2 = 1005
x1 = df.loc[:1004, "OrganicCarbon"].mean()
x2 = df.loc[1005:, "OrganicCarbon"].mean()
s1_2 = df.loc[:1004, "OrganicCarbon"].var()
s2_2 = df.loc[1005:, "OrganicCarbon"].var()
z_value = (x1-x2-0.15)/sqrt(s1_2/n1 + s2_2/n2)
p_value = 2*min(1 - st.norm.cdf(abs(z_value)),st.norm.cdf(abs(z_value)))
print("Nilai z: ", z_value)
print("Nilai p: ", p_value)
# Out:
# Nilai z:  -2.4131455177986747
# Nilai p:  0.01581550381760577

# %% [markdown]
# 6. Nilai z yang didapat berada dalam daerah kritis (-2.413<-1.960) dan p-value < $\alpha$. Oleh karena itu, keputusan yang diambil adalah menolak H0 dan menyimpulkan rata-rata bagian awal dikurangi rata-rata bagian akhir tidak sama dengan 0.15.

# %% [markdown]
# ### c. Rata-rata 100 baris pertama kolom Chloramines sama dengan 100 baris terakhirnya?

# %%
ax = df.loc[:99].boxplot(["Chloramines"])
ax.set_title("Boxplot A1")
plt.show()

# %%
ax = df.loc[1910:2009].boxplot(["Chloramines"])
ax.set_title("Boxplot A2")
plt.show()

# %% [markdown]
# 1. $H0: \mu_{A1} = \mu_{A2}$
# 2. $H1: \mu_{A1} \neq \mu_{A2}$
# 3. $\alpha = 0.05$
# 4. Menentukan daerah kritis dengan distribusi normal dan uji statistik two-sample: test on two mean with known variances. note: Saat n>30, distribusi t tidak berbeda signifikan dengan distribusi normal dan S estimasi yang baik untuk $\sigma$.

# %%
za = st.norm.ppf(1-0.025)
print("Batas bawah: ",za)
print("Batas atas: ", -za)
# Out:
# Batas bawah:  1.959963984540054
# Batas atas:  -1.959963984540054

# %% [markdown]
# Didapat daerah kritis: $z < -z_{\alpha/2}$ or $z > z_{\alpha/2}$: $z < -1.960$ or $z > 1.960$
# 5. Menghitung nilai uji statistik dan p-value

# %%
from math import sqrt
n1 = 100
n2 = 100
x1 = df.loc[:99, "Chloramines"].mean()
x2 = df.loc[1910:, "Chloramines"].mean()
s1_2 = df.loc[:99, "Chloramines"].var()
s2_2 = df.loc[1910:, "Chloramines"].var()
z_value = (x1-x2)/sqrt(s1_2/n1 + s2_2/n2)
p_value = 2*min(1 - st.norm.cdf(abs(z_value)),st.norm.cdf(abs(z_value)))
print("Nilai z: ", z_value)
print("Nilai p: ", p_value)
# Out:
# Nilai z:  -0.7059424842237142
# Nilai p:  0.4802239060450113

# %% [markdown]
# 6. Didapat nilai z di luar daerah kritis (-1.960<-0.705 < 1.960) dan p-value > $\alpha$. Oleh karena itu, keputusan yang diambil adalah tidak menolak H0 dan menyimpulkan tidak cukup data untuk membantah rata-rata 100 baris pertama kolom Chloramines sama dengan rata-rata 100 baris terakhir kolom Chloramines.

# %% [markdown]
# ### d. Proporsi nilai bagian awal Turbidity yang lebih dari 4, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Turbidity ?

# %%
ax = df.loc[:1004].boxplot(["Turbidity"])
ax.set_title("Boxplot A1")
plt.show()

# %%
ax = df.loc[1005:].boxplot(["Turbidity"])
ax.set_title("Boxplot A2")
plt.show()

# %% [markdown]
# 1. $H0: P(X1>4) = P(X2>4)$
# 2. $H1: P(X1>4) > p(X2>4)$
# 3. $\alpha = 0.05$
# 4. Menentukan daerah kritis dengan distribusi normal.

# %%
z = st.norm.ppf(1-0.05)
print("nilai z-alpha = ", z)
# Out:
# nilai z-alpha =  1.6448536269514722

# %% [markdown]
# Didapat daerah kritis $z > z_{\alpha}$: $z > 1.645$
# 5. Menghitung nilai uji statistik dan p-value

# %%
n1 = 1005
n2 = 1005
awal = df.loc[:1004, "Turbidity"]
akhir = df.loc[1005:, "Turbidity"]
x1 = 0
x2 = 0
for val in awal:
  if(val>4):
    x1 +=1
for val in akhir:
  if(val>4):
    x2 +=1
p1 = x1/n1
p2 = x2/n2
p = (x1+x2)/(n1+n2)
z_value = (p1-p2) / sqrt(p*(1-p)*(1/n1 + 1/n2))
p_value = 1 - st.norm.cdf(abs(z_value))
print("nilai z: ", z_value)
print("nilai p: ", p_value)
# Out:
# nilai z:  -0.13388958661778735
# nilai p:  0.4467449424088169

# %% [markdown]
# 6. Didapat nilai z diluar daerah kritis (-0.133<1.645) dan p-value > $\alpha$. Oleh karena itu, keputusan yang diambil adalah tidak menolak H0 dan menyimpulkan tidak cukup alasan untuk mengklaim proporsi nilai bagian awal Turbidity yang lebih dari 4 lebih besar dari proporsi nilai bagian akhir Turbidity yang lebih dari 4.

# %% [markdown]
# ### e. Bagian awal kolom Sulfate memiliki variansi yang sama dengan bagian akhirnya?

# %%
ax = df.loc[:1004].boxplot(["Sulfate"])
ax.set_title("Boxplot A1")
plt.show()

# %%
ax = df.loc[1005:].boxplot(["Sulfate"])
ax.set_title("Boxplot A2")
plt.show()

# %% [markdown]
# 1. $H0: \sigma_{A1}^2 = \sigma_{A2}^2$
# 2. $H1: \sigma_{A1}^2 \neq \sigma_{A2}^2$
# 3. $\alpha = 0.05$
# 4. Menentukan daerah kritis dengan distribusi f.

# %%
n1 = 1005
n2 = 1005
f_025 = st.f.ppf(1-0.025,n1-1,n2-1)
f_975 = st.f.ppf(1-0.975,n1-1,n2-1)
print("f_(1-a) = ", f_975)
print("f_a = ", f_025)
# Out:
# f_(1-a) =  0.883572344355818
# f_a =  1.1317692392568777

# %% [markdown]
# Didapat daerah kritis $f \lt f_{1-\alpha}$ or $f \gt f_{\alpha}$: $f \lt 0.884$ or $f \gt 1.13$
# 5. Menghitung nilai uji statistik dan p-value

# %%
from math import sqrt
s1_2 = df.loc[:1004, "Sulfate"].var()
s2_2 = df.loc[1005:, "Sulfate"].var()
f_value = s1_2/s2_2
p_value = 2*min(1 - st.f.cdf(f_value, n1-1,n2-1),st.f.cdf(f_value, n1-1,n2-1))
print("Nilai f: ", f_value)
print("Nilai p: ", p_value)
# Out:
# Nilai f:  1.015251104395005
# Nilai p:  0.8105332960349259

# %% [markdown]
# 6. Didapat nilai f di luar daerah kritis (0.884 < 1.015 < 1.13) dan p-value > $\alpha$. Oleh karena itu, keputusan yang diambil adalah tidak menolak H0 dan menyimpulkan variansi bagian awal kolom Sulfate tidak berbeda signifikan dengan variansi bagian akhir kolom Sulfate.

# %% [markdown]
# # Nomor 6
# Test korelasi: tentukan apakah setiap kolom non-target berkorelasi dengan kolom target, dengan menggambarkan juga scatter plot nya. Gunakan correlation test.

# %%
def testKolerasi(df, name):
  sns.regplot(df[name], df["Potability"])
  cor = df[name].corr(df['Potability'])

  print("Nilai korelasi Pearson dari "+name+" : "+str(cor))
  print("Korelasi antara kedua kolom adalah",end=' ')
  if cor == 0:
      print("no correlation")
  elif cor == 1:
      print("perfect positive correlation")
  elif cor == -1:
      print("perfect negative correlation")
  elif 0 < cor < 1:
      print("positive correlation")
  elif -1 < cor < 0:
      print("negative correlation")
  else:
      print("error (nilai korelasi tidak berada pada -1 dan 1)")

# %% [markdown]
# ### pH

# %%
testKolerasi(df, "pH")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari pH : 0.01547509440843346
# Korelasi antara kedua kolom adalah positive correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai positif dengan nilai korelasi 0.0154, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Hardness

# %%
testKolerasi(df, "Hardness")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Hardness : -0.001463152895947929
# Korelasi antara kedua kolom adalah negative correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai negatif dengan nilai korelasi -0.0014, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Solids

# %%
testKolerasi(df, "Solids")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Solids : 0.038976578181734625
# Korelasi antara kedua kolom adalah positive correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai positif dengan nilai korelasi 0.0389, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Chloramines

# %%
testKolerasi(df, "Chloramines")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Chloramines : 0.020778921840524073
# Korelasi antara kedua kolom adalah positive correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai positif dengan nilai korelasi 0.0207, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Sulfate

# %%
testKolerasi(df, "Sulfate")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Sulfate : -0.01570316441927377
# Korelasi antara kedua kolom adalah negative correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai negatif dengan nilai korelasi -0.0157, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Conductivity

# %%
testKolerasi(df, "Conductivity")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Conductivity : -0.016257120111377078
# Korelasi antara kedua kolom adalah negative correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai negatif dengan nilai korelasi -0.0162, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### OrganicCarbon

# %%
testKolerasi(df, "OrganicCarbon")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari OrganicCarbon : -0.015488461910747264
# Korelasi antara kedua kolom adalah negative correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai negatif dengan nilai korelasi -0.0154, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Trihalomethanes

# %%
testKolerasi(df, "Trihalomethanes")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Trihalomethanes : 0.009236711064712997
# Korelasi antara kedua kolom adalah positive correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai positif dengan nilai korelasi 0.0092, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# ### Turbidity

# %%
testKolerasi(df, "Turbidity")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Nilai korelasi Pearson dari Turbidity : 0.022331042640622648
# Korelasi antara kedua kolom adalah positive correlation

# %% [markdown]
# Berdasarkan visiualisasi hasil regresi scatter plot, terlihat bahwa gradien bernilai positif dengan nilai korelasi 0.0223, korelasi tersebut termasuk kategori korelasi sangat lemah.

# %% [markdown]
# # Referensi
# 1. Dokumentasi R - https://www.rdocumentation.org/
# 2. Project Jupyter - http://jupyter.org/
# 3. Pandas - https://pandas.pydata.org/
# 4. Matplotlib - https://matplotlib.org/
# 5. Walpole, dkk. 2012. Probability and Statistics for Engineers and Scientists: Ninth Edition.
